# %%
# Define model
import keras.layers as L
import keras.losses as losses
import keras.models as M
import keras.optimizers as opt
#from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import spacy 
import re
from sklearn import metrics #cross_validation 
from sklearn.model_selection import train_test_split
import seaborn as sns
# %matplotlib inline

# %%
# Plot settings
plt.style.use('seaborn-dark-palette')
plt.interactive(True)
plt.rcParams['figure.figsize'] = (20, 10)

# %%
# GLoVE vector dictionary
vector = None

# %%
df = pd.read_csv('/content/task_1_information_extraction_training_set.tsv',sep='\t')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (2,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(df.shape)
# Out:
# (115668, 30)

# %%
counter = Counter(df.LOCATION)
print("counter1: {}".format(counter))
counter = sorted(counter.items(), key=lambda x: -x[1])[:15]
print("counter2: {}".format(counter))
counter = np.array(counter)

print ([x[0] for x in counter])

places, counts = counter[:, 0].tolist(), counter[:, 1].astype(np.float32)
indices = np.arange(len(counts))
width = 1

plt.xlabel("Location")
plt.ylabel("Number of articles")
plt.interactive(True)

plt.xticks(indices + 0.125, places)
plt.title("Top 10 news generating locations")
_ = plt.bar(indices, counts, 0.5)
# Out:
# counter1: Counter({'Jammu': 2459, 'Srinagar': 1656, 'Delhi - New Delhi': 1404, 'Chandigarh': 1187, 'Ludhiana': 1093, 'Bathinda': 954, 'Amritsar': 872, 'Hyderabad': 861, 'Imphal': 813, 'Kolkata': 796, 'New York - Manhattan': 794, 'Bengaluru': 683, 'Guwahati': 674, 'Chennai': 630, 'Patiala': 608, 'Agartala': 571, 'Jalandhar': 558, 'Lucknow': 477, 'Patna': 463, 'Visakhapatnam': 459, 'Bhubaneswar': 449, 'Thiruvananthapuram': 441, 'Coimbatore': 440, 'Siliguri': 423, 'Salem': 398, 'Dehradun': 397, 'Madurai': 389, 'Ranchi': 376, 'Udhampur': 351, 'Mumbai': 346, 'San Francisco': 345, 'New York - Brooklyn': 330, 'Philadelphia': 321, 'Vijayawada': 320, 'Tarn Taran': 300, 'Boston': 300, 'Washington DC': 300, 'Kathua': 293, 'Atlanta': 293, 'San Diego': 284, 'Puducherry': 283, 'Sangrur': 278, 'Jaipur': 277, 'Pune': 273, 'Kochi': 263, 'Seattle': 262, 'Tiruchirappalli': 251, 'Gurgaon': 248, 'Portland': 244, 'Mohali': 236, 'Jamshedpur': 229, 'Sacramento': 229, 'Los Angeles-Central': 229, 'Bhopal': 228, 'Karnal': 227, 'Denver': 227, 'Miami': 224, 'Austin': 223, 'Pittsburgh': 219, 'Louisville': 216, 'Mysuru': 215, 'Phoenix': 210, 'Dibrugarh': 209, 'Minneapolis': 209, 'Shimla': 206, 'Columbus': 206, 'Ahmedabad': 203, 'Oakland': 202, 'Richmond': 197, 'Shillong': 195, 'Poonch': 193, 'Panchkula': 192, 'Salt Lake City': 190, 'Samba': 189, 'Jorhat': 189, 'Las Vegas': 189, 'Ambala': 181, 'Agra': 179, 'North Lakhimpur': 179, 'Baltimore': 178, 'Kurnool': 175, 'Ongole': 175, 'Los Angeles': 175, 'Springfield': 175, 'Nashville': 172, 'Milwaukee': 170, 'Saint Paul': 170, 'Pulwama': 167, 'Naushera': 166, 'Columbia': 166, 'Chicago': 166, 'Nagpur': 165, 'Allahabad': 165, 'Hiranagar': 164, 'Memphis': 164, 'Anantnag': 163, 'Raleigh': 163, 'Washington DC-National Mall': 162, 'Rochester': 161, 'Albany': 161, 'Charleston': 161, 'Madison': 160, 'Houston': 158, 'Silchar': 156, 'Itanagar': 156, 'Shopian': 155, 'New York - Queens': 154, 'Kansas City': 154, 'Muktsar': 152, 'Thoothukudi': 152, 'Kozhikode': 152, 'Aurangabad': 151, 'Tirunelveli': 151, 'Tirupati': 151, 'Tampa': 151, 'Tinsukia': 150, 'Rajouri': 149, 'Providence': 148, 'Thanjavur': 147, 'Orlando': 145, 'Portland-Downtown': 143, 'Panaji': 142, 'Guntur': 141, 'Khammam': 140, 'Gulbarga': 138, 'Golaghat': 134, 'Meerut': 133, 'Detroit': 133, 'Erode': 131, 'Tallahassee': 131, 'New York - Bronx': 131, 'Jacksonville': 130, 'Mendhar': 129, 'Kishtwar': 129, 'Dispur': 129, 'Albuquerque': 129, 'Saint Louis': 129, 'Dallas': 126, 'Lansing': 126, 'Dhanbad': 124, 'Fazilka': 123, 'Jackson': 123, 'Barnala': 122, 'Hartford': 122, 'Harrisburg': 122, 'San Jose': 121, 'Mangaluru': 120, 'Sopore': 119, 'Raipur': 119, 'Aligarh': 119, 'Noida': 118, 'Wilmington': 117, 'Indore': 116, 'Abohar': 116, 'Honolulu': 116, 'Indianapolis': 114, 'Faridkot': 113, 'Phagwara': 113, 'Oklahoma City': 113, 'Buffalo': 113, 'San Antonio': 113, 'Varanasi': 112, 'Nagaon': 112, 'New Orleans': 112, 'Charlotte': 111, 'Panipat': 110, 'Sivasagar': 109, 'Chicago-Central': 109, 'Knoxville': 109, 'Kakinada': 108, 'Amaravati': 108, 'Eugene': 108, 'Ramanathapuram': 107, 'Rohtak': 107, 'Mansa': 107, 'Dharwad': 105, 'Sunderbani': 105, 'Tiruppur': 103, 'Warangal': 103, 'Des Moines': 103, 'Moga': 102, 'Lakhimpur': 102, 'Shahpur': 101, 'Tral': 101, 'Gainesville': 100, 'Hoshiarpur': 99, 'Cleveland': 99, 'Athens': 98, 'Fresno': 98, 'Thane': 97, 'Baramulla': 97, 'Doom Dooma': 97, 'Dhemaji': 97, 'Bakersfield': 97, 'Surat': 96, 'Dharamsala': 96, 'Ferozepur': 95, 'Kanpur': 95, 'Kokrajhar': 94, 'Kirni': 94, 'Washington DC-Northwest': 94, 'Lexington': 94, 'Vadodara': 93, 'Ranbir Singh Pura': 93, 'Tezpur': 93, 'Boise': 93, 'Shivamogga': 92, 'Hubballi': 92, 'Thoubal': 92, 'Reasi': 91, 'Mandya': 90, 'Dindigul': 90, 'Vizianagaram': 89, 'Muzaffarnagar': 89, 'Hisar': 88, 'Little Rock': 88, 'Bandipora': 87, 'Kulgam': 87, 'Bongaigaon': 87, 'Dharmapuri': 86, 'Ghaziabad': 85, 'Mankote': 85, 'Saint Petersburg': 85, 'Greenville': 85, 'Cuttack': 84, 'Olympia': 84, 'Nashik': 83, 'Kupwara': 83, ...
# counter2: [('Jammu', 2459), ('Srinagar', 1656), ('Delhi - New Delhi', 1404), ('Chandigarh', 1187), ('Ludhiana', 1093), ('Bathinda', 954), ('Amritsar', 872), ('Hyderabad', 861), ('Imphal', 813), ('Kolkata', 796), ('New York - Manhattan', 794), ('Bengaluru', 683), ('Guwahati', 674), ('Chennai', 630), ('Patiala', 608)]
# ['Jammu', 'Srinagar', 'Delhi - New Delhi', 'Chandigarh', 'Ludhiana', 'Bathinda', 'Amritsar', 'Hyderabad', 'Imphal', 'Kolkata', 'New York - Manhattan', 'Bengaluru', 'Guwahati', 'Chennai', 'Patiala']

# %%
month_map = {'January':'1', 'February':'2', 'March':'3', 'April':'4', 'May':'5', 'June':'6', 'July':'7', 'August': '8', 'September':'9', 'October':'10', 'November':'11','December':'12'}
df['EVENT_DATE'] = df['EVENT_DATE'].apply(lambda st: str(st))
df['month'] = df['EVENT_DATE'].map(lambda st: st[st.find("-")+1:st.rfind("-")])
df = df[df['month'] != 'na']
df = df[df['month'] != 'us']  
df['EVENT_DATE'] = df['EVENT_DATE'].map(lambda st: st[:st.find("-")+1] + month_map[st[st.find("-")+1:st.rfind("-")]] + st[st.rfind("-"):])
df['EVENT_DATE'].value_counts()
# Out:
# 06-6-2020     751
# 31-5-2020     670
# 01-6-2020     597
# 02-6-2020     562
# 30-5-2020     552
#              ...
# 01-3-2018      17
# 24-6-2018      14
# 21-3-2020      13
# 14-7-2018      11
# 27-10-2019      9
# Name: EVENT_DATE, Length: 1482, dtype: int64

# %%
print(df['EVENT_DATE'])
# Out:
# 0         01-1-2018
# 1         01-1-2018
# 2         01-1-2018
# 3         01-1-2018
# 4         01-1-2018
#             ...
# 115663    21-1-2022
# 115664    21-1-2022
# 115665    21-1-2022
# 115666    21-1-2022
# 115667    21-1-2022
# Name: EVENT_DATE, Length: 115664, dtype: object

# %%
dates = pd.date_range(start=df.iloc[0]['EVENT_DATE'], end=df.iloc[-1]['EVENT_DATE'])
print("Number of days ", len(dates))
# Out:
# Number of days  1482

# %%
#dates[0], dates[-1]

# %%
print(dates)
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2022-01-12', '2022-01-13', '2022-01-14', '2022-01-15',
#                '2022-01-16', '2022-01-17', '2022-01-18', '2022-01-19',
#                '2022-01-20', '2022-01-21'],
#               dtype='datetime64[ns]', length=1482, freq='D')

# %%
print(len(dates))
# Out:
# 1482

# %%
df["EVENT_DATE_to_datetime"] = pd.to_datetime(df["EVENT_DATE"])

# %%
event_date_list = df["EVENT_DATE"].tolist()
print(event_date_list)
# Out:
# ['01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '01-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '02-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '03-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '04-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '05-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '06-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '07-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-2018', '08-1-20 ...

# %%
import datetime
df = df[df['LOCATION'] == "Jammu"]

num_events = np.zeros(len(dates))
i = 0
for date in dates:
    #print(type(df['EVENT_DATE']))
    # list1=str(df['EVENT_DATE']).split('-')
    # date1=datetime.datetime(int(list1[2],list1[1],list1[0])
    #date_object=datetime.datetime.strptime((df['EVENT_DATE']),'%Y-%m-%d')
    #print(date_object)
    #.strftime('%Y-%m-%d')
    num_events[i] += len(df[df["EVENT_DATE_to_datetime"] == date])
    i += 1

# %%
print(dates)
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2022-01-12', '2022-01-13', '2022-01-14', '2022-01-15',
#                '2022-01-16', '2022-01-17', '2022-01-18', '2022-01-19',
#                '2022-01-20', '2022-01-21'],
#               dtype='datetime64[ns]', length=1482, freq='D')

# %%
print(num_events)
# Out:
# [2. 3. 0. ... 1. 1. 2.]

# %%
plt.title("Number of events over time")
plt.xlabel("TIMESTAMP")
plt.ylabel("Number of events")
_ = plt.bar(np.arange(len(num_events)), num_events)
# _ = plt.bar(np.arange(len(num_events)), num_events)

# %%
news_articles = df.NOTES
df.shape
# Out:
# (2459, 32)

# %%
def get_glove_dict():
    """
    Inputs - None
    
    Returns - Dict below
    
    Create a dict with word as key and word vector as value
    """
    d = {}
    f = open('/content/glove.6B.300d.txt', 'r')
    for row in f:
        row = row.replace('\n', '').split(" ")
        word = row[0]
        vector = np.array([float(x) for x in row[1:]])
        d[word] = vector
    f.close()
    return d

def generate_labels(num_events, num_days=2, days_window=2):
    """
    Inputs - 
        num_events - as generated as above 
        num_days - the number of days to after which we 
                   look for the occurence of an event.
                   Basically, the future
        day_window - If an event occurs in a window of days
                     after num_days
    
    Returns - Returns labels generated as below
    
    Generate labels by using the future events, basically
    look-ahead to create labels. If an event occurs from 
    i to i + num_days, then label is 1.0 else 0.0
    """
    n = len(num_events)
    labels = np.zeros(n - num_days - days_window)
    for i in range(n - num_days - days_window):
        labels[i] = 1.0 if sum(num_events[i + num_days: i + num_days + days_window] > 0) else 0.0
    return labels

# %%
if vector is None:
    vector = get_glove_dict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-a11580dafebe> in <module>()
#       1 if vector is None:
# ----> 2     vector = get_glove_dict()
#
# <ipython-input-62-7fa49485b8af> in get_glove_dict()
#      12         row = row.replace('\n', '').split(" ")
#      13         word = row[0]
# ---> 14         vector = np.array([float(x) for x in row[1:]])
#      15         d[word] = vector
#      16     f.close()
#
# <ipython-input-62-7fa49485b8af> in <listcomp>(.0)
#      12         row = row.replace('\n', '').split(" ")
#      13         word = row[0]
# ---> 14         vector = np.array([float(x) for x in row[1:]])
#      15         d[word] = vector
#      16     f.close()
#
# ValueError: could not convert string to float:

# %%
num_days, days_window = 2, 5
labels = generate_labels(num_events, num_days, days_window)

# %%
plt.title('Label Distribution')
plt.xlabel('Ground Truth')
plt.ylabel('hasEventOcurred')
_ = plt.hist(labels, bins=3, range=(0, 1))

# %%
# Tokenizer
nlp = spacy.load('en_core_web_sm')

# Generate sentence vectors
sentence_vectors = []
regexp = r'/[.,\/#!$%\^&\*;:{}=\-_`~()]/g'
num_sentences = len(news_articles)
print(num_sentences)
for i, sentence in enumerate(news_articles):
    if i % 100 == 0:
        print (i, " / ", num_sentences, "done!")
    tokens = [t.text.lower() for t in nlp(sentence)]
    temp = []
    for token in tokens:
        vec = vector.get(token)
        """if vec is None:
            vec = vector['unk']"""
        temp.append(vec)
    sentence_vectors.append(temp)

# %%
# For the sentence vector, currently, simply just use average of all words vectors
for i, vecs in enumerate(sentence_vectors):
    #print(sentence_vectors[i])
    sentence_vectors[i] = np.mean(vec, axis=0)

# %%
sentence_vectors = np.array(sentence_vectors)
print("Sentence vector shape -", sentence_vectors.shape)

vector_dim = sentence_vectors.shape[0]

# %%
df.index = np.arange(len(df))
df.head(5)

# %%
sentence_dict = {}
for date in dates:
    temp_df = df[df['EVENT_DATE'] == date]
    
    if len(temp_df) == 0:
        sentence_dict[date] = (np.zeros(vector_dim))

    else:
        indices = list(temp_df.index)
        sentence_dict[date] = sentence_vectors[indices]

# %% [markdown]
# ### Using average of averages

# %%
print()

# %%
vec_date = []
#print(sentence_dict)
for date in dates:
    arr = sentence_dict[date]  #.reshape(-1, vector_dim)
    vec_date.append(np.mean(arr, axis=0))

print(vec_date)

# %%
history = 5
n = len(dates)

# %%
x, y = [], []
for i in range(history, n - num_days - days_window):
    x.append(vec_date[i - history: i])
    y.append(labels[i])

# %%
x, y = np.array(x), np.array(y)
# p = np.random.permutation(len(x))
# x, y = x[p], y[p]

# %%
print(x.shape, y.shape)
print(y[:5])

# %%
split = int(len(x) * 0.8)
xtrain, xtest = x[:split], x[split:]
ytrain, ytest = y[:split], y[split:]
ytrain, ytest = to_categorical(ytrain), to_categorical(ytest)

# %%
print( 'xtrain', xtrain.shape)
print( 'ytrain', ytrain.shape)
print( 'xtest', xtest.shape)
print( 'ytest', ytest.shape)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
#from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
import  tensorflow as tf

# %%
print(history, vector_dim)    #this is the input shape
print(xtrain.shape[1], 1)
model = M.Sequential()
#model.add(L.LSTM(30, return_sequences=True, input_shape=(history, vector_dim)))# , kernel_size=3))
model.add(L.LSTM(30, return_sequences=True, input_shape=(history, 1)))# , kernel_size=3))
model.add(L.LeakyReLU())
model.add(L.Dropout(0.2))

#model.add(L.LSTM(15, input_shape=(history, vector_dim)))# , kernel_size=3))
model.add(L.LSTM(15))# , kernel_size=3))
model.add(L.LeakyReLU())
model.add(L.Dropout(0.2))

# model.add(L.GlobalMaxPool1D())

model.add(L.Dense(10))

model.add(L.Dense(2, activation='softmax'))
#opt = tf.keras.optimizers.SGD
opzr = tf.keras.optimizers.Adam(0.001)
model.compile(opzr, loss=losses.binary_crossentropy, metrics=['accuracy'])
model.summary()

# %%
print('Train shape -', xtrain.shape)
print('Test shape -', xtest.shape)

# %%
model.fit(xtrain, ytrain, validation_data=(xtest, ytest), batch_size=32, epochs=20)

# %%
pred = model.predict(xtest)
if len(pred.shape) == 1:
    ytest_ = ytest
else:
    pred = model.predict(xtest) [:, 1]
    threshold = 0.68
    pred[pred > threshold] = 1
    pred[pred <= threshold] = 0
    ytest_ = np.argmax(ytest, axis=1)

# %%
print(metrics.classification_report(ytest_, pred))

# %%
conf_mat = metrics.confusion_matrix(ytest_, pred)
# conf_mat = conf_mat * 100. / np.sum(conf_mat, axis=1, keepdims=True)

# %%
conf_mat

# %%
history = 5
n = len(dates)

# %%
x, y = [], []
for date in dates:
    sentence_vecs = sentence_dict[date]
